# %%
VERSION = '18_v2_22'
FOLD_PATH = '../../00_EDA/00_v2_07/result/' 
MODEL = 'microsoft/deberta-v2-xlarge'
LR = 6e-6 
HEAD_LR = 6e-6 
SEED = 100
TRN_BS = 1
VAL_BS = 1
ACCUM_STEP = 1
EPOCHS = 6 
STOP_EPOCH = 6 
RESTART = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
LOSS = 'xentropy'
HEAD = 'simple'
AUG = 'false' 
MIXUP_ALPHA = 1.0
P_AUG = 0
AUG_STOP_EPOCH = 2
MSD = 'true'
MULTI_LAYERS = 1
EVAL_STEP = -1
NUM_LABELS = 3
NUM_LABELS_2 = 7
ADV_SIFT = 'false'
FP16 = 'true'
WD = 0.01
FREEZE = 'true'
MULTI_TASK = 'false'
W_MT = 1.0 
AWP = 'true'
AWP_LR = 1e-4
AWP_EPS = 1e-3
AWP_START_EPOCH = 1
PRETRAINED_DETECTOR_PATH = f'../../05_Detection/exp/result/05_v2_11/model_seed100_fold0_swa.pth'
MASK_PROB = 0.5
MASK_RATIO = 0.22 
SCHEDULER = 'cosine_hard'
NUM_CYCLES = EPOCHS
CP = 'true'
WINDOW_SIZE = 1024
INNER_LEN = 768 
EDGE_LEN = 128 
BNB = 32

# %%
FOLD = 0

# !python ../code/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
# Out:
# torch 1.10.1
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (24, 6)
# val_df.shape =  (34, 6)
# 2022-08-27 15:31:00.328849: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-08-27 15:31:00.328873: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  18
# num_warmup_steps =  1
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████████████| 3/3 [00:02<00:00,  1.13it/s, loss=2.06]
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.93it/s]
# epoch 1: trn_loss = 2.0612, val_loss = 1.1768, trn_score = -1.0538, val_score = -1.1768
# model (best loss) saved
# model (best score) saved
# lr :  [1.1920960908622313e-06, 1.1920960908622313e-06, 1.1920960908622313e-06]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.58it/s, loss=1.51]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.20it/s]
# epoch 2: trn_loss = 1.5078, val_loss = 1.1364, trn_score = -0.7484, val_score = -1.1364
# model (best loss) saved
# model (best score) saved
# lr :  [7.829732483380231e-07, 7.829732483380231e-07, 7.829732483380231e-07]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.61it/s, loss=2.57]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.24it/s]
# epoch 3: trn_loss = 2.5689, val_loss = 1.0558, trn_score = -1.2831, val_score = -1.0558
# model (best loss) saved
# model (best score) saved
# lr :  [4.493485928111587e-07, 4.493485928111587e-07, 4.493485928111587e-07]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.58it/s, loss=1.53]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.25it/s]
# epoch 4: trn_loss = 1.5292, val_loss = 0.9999, trn_score = -0.7539, val_score = -0.9999
# model (best loss) saved
# model (best score) saved
# lr :  [2.0258331178693125e-07, 2.0258331178693125e-07, 2.0258331178693125e-07]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.55it/s, loss=1.87]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.08it/s]
# epoch 5: trn_loss = 1.8651, val_loss = 0.9622, trn_score = -0.9073, val_score = -0.9622
# model (best loss) saved
# model (best score) saved
# lr :  [5.108070094829431e-08, 5.108070094829431e-08, 5.108070094829431e-08]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.57it/s, loss=1.35]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.18it/s]
# epoch 6: trn_loss = 1.3534, val_loss = 0.9413, trn_score = -0.6621, val_score = -0.9413
# model (best loss) saved
# model (best score) saved
# epoch_best 6, val_loss_best 0.94127, val_score_best -0.94127

# %%
FOLD = 1

# !python ../code/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
# Out:
# torch 1.10.1
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (36, 6)
# val_df.shape =  (22, 6)
# 2022-08-27 15:33:33.434676: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-08-27 15:33:33.434699: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  18
# num_warmup_steps =  1
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████████████| 3/3 [00:03<00:00,  1.08s/it, loss=2.68]
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.74it/s]
# epoch 1: trn_loss = 2.6840, val_loss = 1.7603, trn_score = -1.3555, val_score = -1.7603
# model (best loss) saved
# model (best score) saved
# lr :  [1.1920960908622313e-06, 1.1920960908622313e-06, 1.1920960908622313e-06]
# 100%|██████████████████████████████████| 3/3 [00:02<00:00,  1.18it/s, loss=2.77]
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.88it/s]
# epoch 2: trn_loss = 2.7683, val_loss = 1.7872, trn_score = -1.4090, val_score = -1.7872
# lr :  [7.829732483380231e-07, 7.829732483380231e-07, 7.829732483380231e-07]
# 100%|██████████████████████████████████| 3/3 [00:02<00:00,  1.17it/s, loss=2.95]
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.93it/s]
# epoch 3: trn_loss = 2.9504, val_loss = 1.8061, trn_score = -1.4824, val_score = -1.8061
# lr :  [4.493485928111587e-07, 4.493485928111587e-07, 4.493485928111587e-07]
# 100%|██████████████████████████████████| 3/3 [00:02<00:00,  1.17it/s, loss=2.48]
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.89it/s]
# epoch 4: trn_loss = 2.4783, val_loss = 1.7556, trn_score = -1.2344, val_score = -1.7556
# model (best loss) saved
# model (best score) saved
# lr :  [2.0258331178693125e-07, 2.0258331178693125e-07, 2.0258331178693125e-07]
# 100%|██████████████████████████████████| 3/3 [00:02<00:00,  1.11it/s, loss=2.24]
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.92it/s]
# epoch 5: trn_loss = 2.2371, val_loss = 1.6547, trn_score = -1.1166, val_score = -1.6547
# model (best loss) saved
# model (best score) saved
# lr :  [5.108070094829431e-08, 5.108070094829431e-08, 5.108070094829431e-08]
# 100%|██████████████████████████████████| 3/3 [00:02<00:00,  1.15it/s, loss=2.02]
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.98it/s]
# epoch 6: trn_loss = 2.0203, val_loss = 1.6036, trn_score = -1.0049, val_score = -1.6036
# model (best loss) saved
# model (best score) saved
# epoch_best 6, val_loss_best 1.60361, val_score_best -1.60361

# %%
FOLD = 2

# !python ../code/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
# Out:
# torch 1.10.1
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (32, 6)
# val_df.shape =  (22, 6)
# 2022-08-27 15:35:41.483277: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-08-27 15:35:41.483299: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  18
# num_warmup_steps =  1
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████████████| 3/3 [00:02<00:00,  1.25it/s, loss=2.39]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.79it/s]
# epoch 1: trn_loss = 2.3902, val_loss = 1.5020, trn_score = -1.1996, val_score = -1.5020
# model (best loss) saved
# model (best score) saved
# lr :  [1.1920960908622313e-06, 1.1920960908622313e-06, 1.1920960908622313e-06]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.62it/s, loss=2.43]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  4.11it/s]
# epoch 2: trn_loss = 2.4342, val_loss = 1.3738, trn_score = -1.2237, val_score = -1.3738
# model (best loss) saved
# model (best score) saved
# lr :  [7.829732483380231e-07, 7.829732483380231e-07, 7.829732483380231e-07]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.58it/s, loss=2.32]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.90it/s]
# epoch 3: trn_loss = 2.3175, val_loss = 1.1471, trn_score = -1.1748, val_score = -1.1471
# model (best loss) saved
# model (best score) saved
# lr :  [4.493485928111587e-07, 4.493485928111587e-07, 4.493485928111587e-07]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.60it/s, loss=1.77]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  4.01it/s]
# epoch 4: trn_loss = 1.7662, val_loss = 1.0461, trn_score = -0.8765, val_score = -1.0461
# model (best loss) saved
# model (best score) saved
# lr :  [2.0258331178693125e-07, 2.0258331178693125e-07, 2.0258331178693125e-07]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.56it/s, loss=1.72]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.99it/s]
# epoch 5: trn_loss = 1.7155, val_loss = 1.0217, trn_score = -0.8421, val_score = -1.0217
# model (best loss) saved
# model (best score) saved
# lr :  [5.108070094829431e-08, 5.108070094829431e-08, 5.108070094829431e-08]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.58it/s, loss=1.58]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.97it/s]
# epoch 6: trn_loss = 1.5783, val_loss = 1.0076, trn_score = -0.7959, val_score = -1.0076
# model (best loss) saved
# model (best score) saved
# epoch_best 6, val_loss_best 1.00764, val_score_best -1.00764

# %%
RESTART = 3
MASK_PROB = 0.5
MASK_RATIO = 0.15

FOLD = 2

# !python ../code/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB

RESTART = 1
MASK_PROB = 0.5 
MASK_RATIO = 0.22
# Out:
# torch 1.10.1
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (32, 6)
# val_df.shape =  (22, 6)
# 2022-08-27 15:38:11.492849: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-08-27 15:38:11.492871: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  18
# num_warmup_steps =  1
# epoch =  1
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 12.48it/s]
# epoch =  2
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 16.85it/s]
# lr :  [7.829732483380231e-07, 7.829732483380231e-07, 7.829732483380231e-07]
# 100%|██████████████████████████████████| 3/3 [00:02<00:00,  1.26it/s, loss=2.36]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.77it/s]
# epoch 3: trn_loss = 2.3580, val_loss = 1.5020, trn_score = -1.1678, val_score = -1.5020
# model (best loss) saved
# model (best score) saved
# lr :  [4.493485928111587e-07, 4.493485928111587e-07, 4.493485928111587e-07]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.59it/s, loss=2.03]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  4.04it/s]
# epoch 4: trn_loss = 2.0280, val_loss = 1.4506, trn_score = -1.0058, val_score = -1.4506
# model (best loss) saved
# model (best score) saved
# lr :  [2.0258331178693125e-07, 2.0258331178693125e-07, 2.0258331178693125e-07]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.59it/s, loss=2.37]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  4.03it/s]
# epoch 5: trn_loss = 2.3670, val_loss = 1.2859, trn_score = -1.1785, val_score = -1.2859
# model (best loss) saved
# model (best score) saved
# lr :  [5.108070094829431e-08, 5.108070094829431e-08, 5.108070094829431e-08]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.57it/s, loss=2.03]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.43it/s]
# epoch 6: trn_loss = 2.0295, val_loss = 1.1656, trn_score = -1.0339, val_score = -1.1656
# model (best loss) saved
# model (best score) saved
# epoch_best 6, val_loss_best 1.16560, val_score_best -1.16560

# %%
FOLD = 3

# !python ../code/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
# Out:
# torch 1.10.1
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (34, 6)
# val_df.shape =  (29, 6)
# 2022-08-27 15:40:14.822468: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-08-27 15:40:14.822492: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  18
# num_warmup_steps =  1
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████████████| 3/3 [00:03<00:00,  1.23s/it, loss=3.04]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.73it/s]
# epoch 1: trn_loss = 3.0359, val_loss = 1.1423, trn_score = -1.5450, val_score = -1.1423
# model (best loss) saved
# model (best score) saved
# lr :  [1.1920960908622313e-06, 1.1920960908622313e-06, 1.1920960908622313e-06]
# 100%|██████████████████████████████████| 3/3 [00:03<00:00,  1.01s/it, loss=2.48]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.87it/s]
# epoch 2: trn_loss = 2.4769, val_loss = 1.1597, trn_score = -1.2049, val_score = -1.1597
# lr :  [7.829732483380231e-07, 7.829732483380231e-07, 7.829732483380231e-07]
# 100%|██████████████████████████████████| 3/3 [00:03<00:00,  1.04s/it, loss=2.94]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.99it/s]
# epoch 3: trn_loss = 2.9420, val_loss = 1.1472, trn_score = -1.4498, val_score = -1.1472
# lr :  [4.493485928111587e-07, 4.493485928111587e-07, 4.493485928111587e-07]
# 100%|██████████████████████████████████| 3/3 [00:03<00:00,  1.01s/it, loss=2.42]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.94it/s]
# epoch 4: trn_loss = 2.4248, val_loss = 1.0628, trn_score = -1.2114, val_score = -1.0628
# model (best loss) saved
# model (best score) saved
# lr :  [2.0258331178693125e-07, 2.0258331178693125e-07, 2.0258331178693125e-07]
# 100%|██████████████████████████████████| 3/3 [00:03<00:00,  1.02s/it, loss=2.25]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.95it/s]
# epoch 5: trn_loss = 2.2507, val_loss = 0.9866, trn_score = -1.1360, val_score = -0.9866
# model (best loss) saved
# model (best score) saved
# lr :  [5.108070094829431e-08, 5.108070094829431e-08, 5.108070094829431e-08]
# 100%|██████████████████████████████████| 3/3 [00:03<00:00,  1.04s/it, loss=2.09]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  4.00it/s]
# epoch 6: trn_loss = 2.0928, val_loss = 0.9536, trn_score = -1.0268, val_score = -0.9536
# model (best loss) saved
# model (best score) saved
# epoch_best 6, val_loss_best 0.95355, val_score_best -0.95355

# %%
FOLD = 4

# !python ../code/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
# Out:
# torch 1.10.1
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (32, 6)
# val_df.shape =  (34, 6)
# 2022-08-27 15:42:27.566915: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-08-27 15:42:27.566938: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  18
# num_warmup_steps =  1
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████████████| 3/3 [00:02<00:00,  1.24it/s, loss=2.15]
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.71it/s]
# epoch 1: trn_loss = 2.1467, val_loss = 1.1664, trn_score = -1.0649, val_score = -1.1664
# model (best loss) saved
# model (best score) saved
# lr :  [1.1920960908622313e-06, 1.1920960908622313e-06, 1.1920960908622313e-06]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.57it/s, loss=1.79]
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.94it/s]
# epoch 2: trn_loss = 1.7890, val_loss = 1.1502, trn_score = -0.8958, val_score = -1.1502
# model (best loss) saved
# model (best score) saved
# lr :  [7.829732483380231e-07, 7.829732483380231e-07, 7.829732483380231e-07]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.57it/s, loss=1.95]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.01it/s]
# epoch 3: trn_loss = 1.9541, val_loss = 1.1496, trn_score = -0.9582, val_score = -1.1496
# model (best loss) saved
# model (best score) saved
# lr :  [4.493485928111587e-07, 4.493485928111587e-07, 4.493485928111587e-07]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.62it/s, loss=1.68]
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.96it/s]
# epoch 4: trn_loss = 1.6834, val_loss = 1.1358, trn_score = -0.8394, val_score = -1.1358
# model (best loss) saved
# model (best score) saved
# lr :  [2.0258331178693125e-07, 2.0258331178693125e-07, 2.0258331178693125e-07]
# 100%|███████████████████████████████████| 3/3 [00:01<00:00,  1.55it/s, loss=2.4]
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.90it/s]
# epoch 5: trn_loss = 2.4034, val_loss = 1.1215, trn_score = -1.1893, val_score = -1.1215
# model (best loss) saved
# model (best score) saved
# lr :  [5.108070094829431e-08, 5.108070094829431e-08, 5.108070094829431e-08]
# 100%|██████████████████████████████████| 3/3 [00:01<00:00,  1.59it/s, loss=2.38]
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.97it/s]
# epoch 6: trn_loss = 2.3827, val_loss = 1.1096, trn_score = -1.1669, val_score = -1.1096
# model (best loss) saved
# model (best score) saved
# epoch_best 6, val_loss_best 1.10957, val_score_best -1.10957

# %% [markdown]
# # SWA

# %%
# !python ../code/swa.py --work_dir ./result/$VERSION/ --fold 0 --seed $SEED --epochs '4'
# !python ../code/swa.py --work_dir ./result/$VERSION/ --fold 1 --seed $SEED --epochs '4 5'
# !python ../code/swa.py --work_dir ./result/$VERSION/ --fold 2 --seed $SEED --epochs '4 5 6'
# !python ../code/swa.py --work_dir ./result/$VERSION/ --fold 3 --seed $SEED --epochs '4'
# !python ../code/swa.py --work_dir ./result/$VERSION/ --fold 4 --seed $SEED --epochs '2 3 4 5'
